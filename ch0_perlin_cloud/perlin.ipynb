# %%
# !pip install perlin-noise
# !pip install matplotlib
# !pip install numpy
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.0; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.0; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.0; however, version 21.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 75 kB 5.3 MB/s
# ...
# WARNING: You are using pip version 21.0; however, version 21.1.1 is available.
# ...

# %%
from perlin_noise import PerlinNoise
from matplotlib import pyplot as plt
import numpy as np
import colorsys
import tqdm

# %%
value_noise = PerlinNoise(octaves=6, seed=3)
hue_noise = PerlinNoise(octaves=2, seed=2)
nrows, ncols = 100, 100

img = np.zeros([nrows, ncols, 3], dtype=np.uint8)
pbar = tqdm.tqdm(desc="pxl", total=nrows*ncols)
for y in range(nrows):
    for x in range(ncols):
        hue_ratio = hue_noise((x/ncols, y/nrows))
        saturation_ratio = 1.0
        value_coord = (hue_xc + x*hue_scale, hue_yc + y*hue_scale)
        value_ratio = value_noise((x/ncols, y/nrows))
        rgb = np.array(colorsys.hsv_to_rgb(hue_ratio, 1.0, value_ratio))
        img[y,x,:] = rgb*255
        pbar.update()
# Out:
# pxl:   0%|          | 0/10000 [00:00<?, ?it/s]
#
#
# pxl:   4%|▍         | 395/10000 [00:00<00:02, 3948.27it/s]
#
#
# pxl:   8%|▊         | 790/10000 [00:00<00:02, 3893.83it/s]
#
#
# pxl:  12%|█▏        | 1180/10000 [00:00<00:02, 3891.31it/s]
#
#
# pxl:  16%|█▌        | 1570/10000 [00:00<00:02, 3807.01it/s]
#
#
# pxl:  20%|█▉        | 1951/10000 [00:00<00:02, 3800.03it/s]
#
#
# pxl:  23%|██▎       | 2345/10000 [00:00<00:01, 3846.82it/s]
#
#
# pxl:  27%|██▋       | 2730/10000 [00:00<00:01, 3826.92it/s]
#
#
# pxl:  31%|███       | 3113/10000 [00:00<00:01, 3801.24it/s]
#
#
# pxl:  35%|███▍      | 3494/10000 [00:00<00:01, 3694.83it/s]
#
#
# pxl:  39%|███▉      | 3887/10000 [00:01<00:01, 3763.19it/s]
#
#
# pxl:  43%|████▎     | 4268/10000 [00:01<00:01, 3776.17it/s]
#
#
# pxl:  47%|████▋     | 4654/10000 [00:01<00:01, 3799.08it/s]
#
#
# pxl:  50%|█████     | 5041/10000 [00:01<00:01, 3819.39it/s]
#
#
# pxl:  54%|█████▍    | 5432/10000 [00:01<00:01, 3844.31it/s]
#
#
# ...

# %%
plt.imshow(img)
plt.show()
